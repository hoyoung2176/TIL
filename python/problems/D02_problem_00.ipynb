# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint #
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
print(btc)
# Out:
# {'opening_price': '4327000', 'closing_price': '4296000', 'min_price': '4250000', 'max_price': '4339000', 'average_price': '4298829.1309', 'units_traded': '18172.74691429', 'volume_1day': '18172.74691429', 'volume_7day': '56075.99683167', 'buy_price': '4289000', 'sell_price': '4295000', '24H_fluctate': '-31000', '24H_fluctate_rate': '-0.71', 'date': '1546574541510'}

# %%
# 아래에 코드를 작성하세요.
# 시가는 오프닝값 변동폭 min,max차이

# print("상승장") if float(btc["max_price"]) < float(btc["opening_price"]) + (float(btc["max_price"]) - float(btc["min_price"])) else print("하락장")

bdp = float(btc["max_price"])-float(btc["min_price"])
if int(btc["opening_price"]) + bdp > int(btc["max_price"]):
    print("상승장") 
else:
    print("하락장")
# Out:
# 상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
print(currency)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e501baddffd4> in <module>
# ----> 1 currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
#       2 print(currency)
#
# NameError: name 'requests' is not defined

# %%
# 아래에 코드를 작성하세요.
# print("상승장") if float(btc["max_price"]) < float(btc["opening_price"]) + (float(btc["max_price"]) - float(btc["min_price"])) else print("하락장")

# bdp = float(current['BTC']["max_price"])-float(current['BTC']["min_price"])
# if int(current['BTC']["opening_price"]) + bdp > int(current['BTC']["max_price"]):
#     print("상승장") 
# else:
#     print("하락장")
# 첫조건을 딕셔너리만 읽기 
for key, value in currency.items():
    if type(value) == type(dict()):
        bdp = float(value["max_price"])-float(value["min_price"])
        if float(value["opening_price"]) + bdp > float(value["max_price"]):
            print(f'{key:5} 상승장') #5번띄어쓰기
        else:
            print(f'{key:5} 하락장')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2a99d215980e> in <module>
#       8 #     print("하락장")
#       9 # 첫조건을 딕셔너리만 읽기
# ---> 10 for key, value in currency.items():
#      11     if type(value) == type(dict()):
#      12         bdp = float(value["max_price"])-float(value["min_price"])
#
# NameError: name 'currency' is not defined

# %%
currency
# Out:
# {'BTC': {'opening_price': '4320000',
#   'closing_price': '4275000',
#   'min_price': '4250000',
#   'max_price': '4339000',
#   'average_price': '4300999.1466',
#   'units_traded': '18058.73106827',
#   'volume_1day': '18058.73106827',
#   'volume_7day': '56224.25563717',
#   'buy_price': '4275000',
#   'sell_price': '4277000',
#   '24H_fluctate': '-45000',
#   '24H_fluctate_rate': '-1.04'},
#  'ETH': {'opening_price': '171000',
#   'closing_price': '166800',
#   'min_price': '163500',
#   'max_price': '173800',
#   'average_price': '168123.637',
#   'units_traded': '580974.44824891',
#   'volume_1day': '580974.44824891',
#   'volume_7day': '1972433.069420816188046675',
#   'buy_price': '166700',
#   'sell_price': '166900',
#   '24H_fluctate': '-4200',
#   '24H_fluctate_rate': '-2.45'},
#  'DASH': {'opening_price': '93550',
#   'closing_price': '90600',
#   'min_price': '88100',
#   'max_price': '93600',
#   'average_price': '90708.5586',
#   'units_traded': '3692999.64593308',
# ...
