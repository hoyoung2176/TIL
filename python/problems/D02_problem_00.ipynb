# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint #
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
print(btc)
# Out:
# {'opening_price': '3865000', 'closing_price': '3796000', 'min_price': '3780000', 'max_price': '3879000', 'average_price': '3824797.4311', 'units_traded': '3825.05118804', 'volume_1day': '3825.05118804', 'volume_7day': '21306.72146211', 'buy_price': '3795000', 'sell_price': '3796000', '24H_fluctate': '-69000', '24H_fluctate_rate': '-1.78', 'date': '1548735367976'}

# %%
# 아래에 코드를 작성하세요.
# 시가는 오프닝값 변동폭 min,max차이

# print("상승장") if float(btc["max_price"]) < float(btc["opening_price"]) + (float(btc["max_price"]) - float(btc["min_price"])) else print("하락장")

bdp = float(btc["max_price"])-float(btc["min_price"])
if int(btc["opening_price"]) + bdp > int(btc["max_price"]):
    print("상승장") 
else:
    print("하락장")
# Out:
# 상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
print(currency)
# Out:
# {'BTC': {'opening_price': '3866000', 'closing_price': '3796000', 'min_price': '3780000', 'max_price': '3879000', 'average_price': '3824793.109', 'units_traded': '3824.76638804', 'volume_1day': '3824.76638804', 'volume_7day': '21306.72146211', 'buy_price': '3795000', 'sell_price': '3797000', '24H_fluctate': '-70000', '24H_fluctate_rate': '-1.81'}, 'ETH': {'opening_price': '120000', 'closing_price': '116000', 'min_price': '112800', 'max_price': '120400', 'average_price': '117100.0821', 'units_traded': '100531.65716725', 'volume_1day': '100531.65716725', 'volume_7day': '426378.176464130992160169', 'buy_price': '115800', 'sell_price': '116000', '24H_fluctate': '-4000', '24H_fluctate_rate': '-3.33'}, 'DASH': {'opening_price': '75250', 'closing_price': '74000', 'min_price': '72900', 'max_price': '76800', 'average_price': '74404.4557', 'units_traded': '6559604.062136', 'volume_1day': '6559604.062136', 'volume_7day': '37319413.17173141', 'buy_price': '73800', 'sell_price': '74000', '24H_fluctate': '-1250', '24H_fluctate_rate': '-1.66'}, 'LTC': {'opening_price': '34780', 'closing_price': '34090', 'min_price': '33500', 'max_price': '34880', 'average_price': '34192.391', 'units_traded': '8044.38448403', 'volume_1day': '8044.38448403', 'volume_7day': '65236.70114165', 'buy_price': '34010', 'sell_price': '34090', '24H_fluctate': '-690', '24H_fluctate_rate': '-1.98'}, 'ETC': {'opening_price': '4511', 'closing_price': '4351', 'min_price': '4219', 'max_price': '4525', 'average_price': '4367.4888', 'units_traded': '56387.21261803', 'volume_1day': '56387.21261803', 'volume_7day': '304728.773540292426022459', 'buy_price': '4342', 'sell_price': '4352', '24H_fluctate': '-160', '24H_fluctate_rate': '-3.54'}, 'XRP': {'opening_price': '332', 'closing_price': '322', 'min_price': '313', 'max_price': '333', 'average_price': '324.0033', 'units_traded': '51385401.75764017', 'volume_1day': '51385401.75764017', 'volume_7day': '200319565.27169364', 'buy_price': '321', 'sell_price': '322', '24H_fluctate': '-10', '24H_fluctate_rate': '-3.01'}, 'BCH': {'opening_price': '127300', 'closing_price': '120800', 'min_price': '117000', 'max_price': '128000', 'average_price': '122704.092', 'units_traded': '37426.93509803', 'volume_1day': '37426.93509803', 'volume_7day': '173483.5203404', 'buy_price': '120800', 'sell_price': '120900', '24H_fluctate': '-6500', '24H_fluctate_rate': '-5.10'}, 'XMR': {'opening_price': '49360', 'closing_price': '47900', 'min_price': '47570', 'max_price': '49750', 'average_price': '48465.9254', 'units_traded': '1935303.70480334', 'volume_1day': '1935303.70480334', 'volume_7day': '27847030.07715981668', 'buy_price': '47900', 'sell_price': '48250', '24H_fluctate': '-1460', '24H_fluctate_rate': '-2.95'}, 'ZEC': {'opening_price': '55100', 'closing_price': '53400', 'min_price': '53150', 'max_price': '56400', 'average_price': '54404.4527', 'units_traded': '10264864.16295454', 'volume_1day': '10264864.16295454', 'volume_7day': '63080060.68749792', 'buy_price': '53200', 'sell_price': '53400', '24H_fluctate': '-1700', '24H_fluctate_rate': '-3.08'}, 'QTUM': {'opening_price': '2060', 'closing_price': '2031', 'min_price': '1970', 'max_price': '2150', 'average_price': '2044.4669', 'units_traded': '240461.58109019', 'volume_1day': '240461.58109019', 'volume_7day': '1089005.56092216', 'buy_price': '2030', 'sell_price': '2034', '24H_fluctate': '-29', '24H_fluctate_rate': '-1.40'}, 'BTG': {'opening_price': '10570', 'closing_price': '10600', 'min_price': '10100', 'max_price': '10790', 'average_price': '10464.9654', 'units_traded': '18788460.58241654', 'volume_1day': '18788460.58241654', 'volume_7day': '134331698.76055153', 'buy_price': '10540', 'sell_price': '10600', '24H_fluctate': '30', '24H_fluctate_rate': '0.28'}, 'EOS': {'opening_price': '2547', 'closing_price': '2464', 'min_price': '2404', 'max_price': '2560', 'average_price': '2499.2149', 'units_traded': '2158391.53965057', 'volume_1day': '2158391.53965057', 'volume_7day': '9727222.03272152', 'buy_price' ...

# %%
# 아래에 코드를 작성하세요.
# print("상승장") if float(btc["max_price"]) < float(btc["opening_price"]) + (float(btc["max_price"]) - float(btc["min_price"])) else print("하락장")

# bdp = float(current['BTC']["max_price"])-float(current['BTC']["min_price"])
# if int(current['BTC']["opening_price"]) + bdp > int(current['BTC']["max_price"]):
#     print("상승장") 
# else:
#     print("하락장")
# 첫조건을 딕셔너리만 읽기 
for key, value in currency.items():
    if type(value) == type(dict()):
        bdp = float(value["max_price"])-float(value["min_price"])
        if float(value["opening_price"]) + bdp > float(value["max_price"]):
            print(f'{key:5} 상승장') #5번띄어쓰기
        else:
            print(f'{key:5} 하락장')
# Out:
# BTC   상승장
# ETH   상승장
# DASH  상승장
# LTC   상승장
# ETC   상승장
# XRP   상승장
# BCH   상승장
# XMR   상승장
# ZEC   상승장
# QTUM  상승장
# BTG   상승장
# EOS   상승장
# ICX   상승장
# VET   상승장
# TRX   상승장
# ELF   상승장
# MITH  상승장
# MCO   상승장
# OMG   상승장
# KNC   상승장
# GNT   상승장
# ZIL   상승장
# ETHOS 상승장
# PAY   상승장
# WAX   상승장
# POWR  상승장
# LRC   상승장
# GTO   상승장
# STEEM 상승장
# STRAT 상승장
# ZRX   상승장
# REP   상승장
# AE    상승장
# XEM   상승장
# SNT   상승장
# ADA   상승장
# PPT   상승장
# CTXC  상승장
# CMT   상승장
# THETA 상승장
# WTC   상승장
# ITC   상승장
# TRUE  상승장
# ABT   상승장
# RNT   상승장
# PLY   상승장
# WAVES 상승장
# LINK  상승장
# ENJ   상승장
# PST   상승장
# SALT  상승장
# RDN   상승장
# LOOM  상승장
# BHPC  상승장
# PIVX  상승장
# INS   상승장
# BCD   상승장
# BZNT  상승장
# XLM   상승장
# OCN   상승장
# BSV   상승장
# TMTG  상승장
# BAT   상승장
# WET   상승장
# XVG   상승장
# IOST  상승장
# POLY  상승장
# HC    상승장
# ROM   상승장
# AMO   상승장
# ETZ   하락장
# ARN   상승장
# APIS  상승장
# MTL   상승장

# %%
currency
# Out:
# {'BTC': {'opening_price': '3866000',
#   'closing_price': '3796000',
#   'min_price': '3780000',
#   'max_price': '3879000',
#   'average_price': '3824793.109',
#   'units_traded': '3824.76638804',
#   'volume_1day': '3824.76638804',
#   'volume_7day': '21306.72146211',
#   'buy_price': '3795000',
#   'sell_price': '3797000',
#   '24H_fluctate': '-70000',
#   '24H_fluctate_rate': '-1.81'},
#  'ETH': {'opening_price': '120000',
#   'closing_price': '116000',
#   'min_price': '112800',
#   'max_price': '120400',
#   'average_price': '117100.0821',
#   'units_traded': '100531.65716725',
#   'volume_1day': '100531.65716725',
#   'volume_7day': '426378.176464130992160169',
#   'buy_price': '115800',
#   'sell_price': '116000',
#   '24H_fluctate': '-4000',
#   '24H_fluctate_rate': '-3.33'},
#  'DASH': {'opening_price': '75250',
#   'closing_price': '74000',
#   'min_price': '72900',
#   'max_price': '76800',
#   'average_price': '74404.4557',
#   'units_traded': '6559604.062136',
#   'volume_1day': '6559604.062136',
#   'volume_7day': '37319413.17173141',
#   'buy_price': '73800',
#   'sell_price': '74000',
#   '24H_fluctate': '-1250',
#   '24H_fluctate_rate': '-1.66'},
#  'LTC': {'opening_price': '34780',
#   'closing_price': '34090',
#   'min_price': '33500',
#   'max_price': '34880',
#   'average_price': '34192.391',
#   'units_traded': '8044.38448403',
#   'volume_1day': '8044.38448403',
#   'volume_7day': '65236.70114165',
#   'buy_price': '34010',
#   'sell_price': '34090',
#   '24H_fluctate': '-690',
#   '24H_fluctate_rate': '-1.98'},
#  'ETC': {'opening_price': '4511',
#   'closing_price': '4351',
#   'min_price': '4219',
#   'max_price': '4525',
#   'average_price': '4367.4888',
#   'units_traded': '56387.21261803',
#   'volume_1day': '56387.21261803',
#   'volume_7day': '304728.773540292426022459',
#   'buy_price': '4342',
#   'sell_price': '4352',
#   '24H_fluctate': '-160',
#   '24H_fluctate_rate': '-3.54'},
#  'XRP': {'opening_price': '332',
#   'closing_price': '322',
#   'min_price': '313',
#   'max_price': '333',
#   'average_price': '324.0033',
#   'units_traded': '51385401.75764017',
#   'volume_1day': '51385401.75764017',
#   'volume_7day': '200319565.27169364',
#   'buy_price': '321',
#   'sell_price': '322',
#   '24H_fluctate': '-10',
#   '24H_fluctate_rate': '-3.01'},
#  'BCH': {'opening_price': '127300',
#   'closing_price': '120800',
#   'min_price': '117000',
#   'max_price': '128000',
#   'average_price': '122704.092',
#   'units_traded': '37426.93509803',
#   'volume_1day': '37426.93509803',
#   'volume_7day': '173483.5203404',
#   'buy_price': '120800',
#   'sell_price': '120900',
#   '24H_fluctate': '-6500',
#   '24H_fluctate_rate': '-5.10'},
#  'XMR': {'opening_price': '49360',
#   'closing_price': '47900',
#   'min_price': '47570',
#   'max_price': '49750',
#   'average_price': '48465.9254',
#   'units_traded': '1935303.70480334',
#   'volume_1day': '1935303.70480334',
#   'volume_7day': '27847030.07715981668',
#   'buy_price': '47900',
#   'sell_price': '48250',
#   '24H_fluctate': '-1460',
#   '24H_fluctate_rate': '-2.95'},
#  'ZEC': {'opening_price': '55100',
#   'closing_price': '53400',
#   'min_price': '53150',
#   'max_price': '56400',
#   'average_price': '54404.4527',
#   'units_traded': '10264864.16295454',
#   'volume_1day': '10264864.16295454',
#   'volume_7day': '63080060.68749792',
#   'buy_price': '53200',
#   'sell_price': '53400',
#   '24H_fluctate': '-1700',
#   '24H_fluctate_rate': '-3.08'},
#  'QTUM': {'opening_price': '2060',
#   'closing_price': '2031',
#   'min_price': '1970',
#   'max_price': '2150',
#   'average_price': '2044.4669',
#   'units_traded': '240461.58109019',
#   'volume_1day': '240461.58109019',
#   'volume_7day': '1089005.56092216',
#   'buy_price': '2030',
#   'sell_price': '2034',
#   '24H_fluctate': '-29',
#   '24H_fluctate_rate': '-1.40'},
#  'BTG': {'opening_price': '10570',
#   'closing_price': '10600',
#   'min_price': '10100',
#   'max_price': '10790',
#   'average_price': '10464.9654',
#   'units_traded': '18788460.58241654',
#   'volume_1day': '18788460.58241654',
#   'volume_7day': '134331698.76055153',
#   'buy_price': '10540',
#   'sell_price': '10600',
#   '24H_fluctate': '30',
#   '24H_fluctate_rate': '0.28'},
#  'EOS': {'opening_price': '2547',
#   'closing_price': '2464',
#   'min_price': '2404',
#   'max_price': '2560',
#   'average_price': '2499.2149',
#   'units_traded': '2158391.53965057',
#   'volume_1day': '2158391.53965057',
#   'volume_7day': '9727222.03272152',
#   'buy_price': '2463',
#   'sell_price': '2466',
#   '24H_fluctate': '-83',
#   '24H_fluctate_rate': '-3.25'},
#  'ICX': {'opening_price': '229',
#   'closing_price': '223',
#   'min_price': '217',
#   'max_price': '245',
#   'average_price': '226.2389',
#   'units_traded': '360377.49120108',
#   'volume_1day': '360377.49120108',
#   'volume_7day': '2777111.038429379674227402',
#   'buy_price': '224',
#   'sell_price': '228',
#   '24H_fluctate': '-6',
#   '24H_fluctate_rate': '-2.62'},
#  'VET': {'opening_price': '4.36',
#   'closing_price': '4.25',
#   'min_price': '4.16',
#   'max_price': '4.45',
#   'average_price': '4.2817',
#   'units_traded': '93268968.23212072',
#   'volume_1day': '93268968.23212072',
#   'volume_7day': '1687234179.528108664169337075',
#   'buy_price': '4.22',
#   'sell_price': '4.25',
#   '24H_fluctate': '-0.11',
#   '24H_fluctate_rate': '-2.52'},
#  'TRX': {'opening_price': '29.8',
#   'closing_price': '29.6',
#   'min_price': '28.1',
#   'max_price': '31.4',
#   'average_price': '29.9849',
#   'units_traded': '2148207514.49146757',
#   'volume_1day': '2148207514.49146757',
#   'volume_7day': '4508357389.29267872',
#   'buy_price': '29.6',
#   'sell_price': '29.7',
#   '24H_fluctate': '-0.2',
#   '24H_fluctate_rate': '-0.67'},
#  'ELF': {'opening_price': '110',
#   'closing_price': '114',
#   'min_price': '108',
#   'max_price': '125',
#   'average_price': '114.9738',
#   'units_traded': '3682374.06729922',
#   'volume_1day': '3682374.06729922',
#   'volume_7day': '15747774.504265019537578241',
#   'buy_price': '113',
#   'sell_price': '114',
#   '24H_fluctate': '4',
#   '24H_fluctate_rate': '3.63'},
#  'MITH': {'opening_price': '48.8',
#   'closing_price': '46.9',
#   'min_price': '45.3',
#   'max_price': '49.3',
#   'average_price': '47.12',
#   'units_traded': '9780256.87630358',
#   'volume_1day': '9780256.87630358',
#   'volume_7day': '48867320.675865563918815793',
#   'buy_price': '46.8',
#   'sell_price': '47.3',
#   '24H_fluctate': '-1.9',
#   '24H_fluctate_rate': '-3.89'},
#  'MCO': {'opening_price': '2202',
#   'closing_price': '2179',
#   'min_price': '2150',
#   'max_price': '2409',
#   'average_price': '2205.5136',
#   'units_traded': '28298.03132646',
#   'volume_1day': '28298.03132646',
#   'volume_7day': '95683.8924715',
#   'buy_price': '2176',
#   'sell_price': '2239',
#   '24H_fluctate': '-23',
#   '24H_fluctate_rate': '-1.04'},
#  'OMG': {'opening_price': '1234',
#   'closing_price': '1220',
#   'min_price': '1185',
#   'max_price': '1251',
#   'average_price': '1222.4025',
#   'units_traded': '162759749.10032185',
#   'volume_1day': '162759749.10032185',
#   'volume_7day': '450483307.171293380816513991',
#   'buy_price': '1213',
#   'sell_price': '1221',
#   '24H_fluctate': '-14',
#   '24H_fluctate_rate': '-1.13'},
#  'KNC': {'opening_price': '136',
#   'closing_price': '132',
#   'min_price': '130',
#   'max_price': '136',
#   'average_price': '132.8436',
#   'units_traded': '864166.99907059',
#   'volume_1day': '864166.99907059',
#   'volume_7day': '4725126.045019997503071948',
#   'buy_price': '132',
#   'sell_price': '133',
#   '24H_fluctate': '-4',
#   '24H_fluctate_rate': '-2.94'},
#  'GNT': {'opening_price': '66.4',
#   'closing_price': '62.8',
#   'min_price': '62.2',
#   'max_price': '66.7',
#   'average_price': '64.1311',
#   'units_traded': '1492133.19403568',
#   'volume_1day': '1492133.19403568',
#   'volume_7day': '7421905.617718884663091948',
#   'buy_price': '62.8',
#   'sell_price': '63',
#   '24H_fluctate': '-3.6',
#   '24H_fluctate_rate': '-5.42'},
#  'ZIL': {'opening_price': '22.8',
#   'closing_price': '22.3',
#   'min_price': '21.3',
#   'max_price': '24.1',
#   'average_price': '22.9898',
#   'units_traded': '83317756.43656655',
#   'volume_1day': '83317756.43656655',
#   'volume_7day': '414794781.095074147448',
#   'buy_price': '22.2',
#   'sell_price': '22.3',
#   '24H_fluctate': '-0.5',
#   '24H_fluctate_rate': '-2.19'},
#  'ETHOS': {'opening_price': '156',
#   'closing_price': '173',
#   'min_price': '146',
#   'max_price': '183',
#   'average_price': '166.2506',
#   'units_traded': '5455463.54647935',
#   'volume_1day': '5455463.54647935',
#   'volume_7day': '28272127.61039497',
#   'buy_price': '171',
#   'sell_price': '173',
#   '24H_fluctate': '17',
#   '24H_fluctate_rate': '10.89'},
#  'PAY': {'opening_price': '267',
#   'closing_price': '302',
#   'min_price': '260',
#   'max_price': '324',
#   'average_price': '288.4898',
#   'units_traded': '6347388.99249128',
#   'volume_1day': '6347388.99249128',
#   'volume_7day': '117886955.904526258028574784',
#   'buy_price': '301',
#   'sell_price': '302',
#   '24H_fluctate': '35',
#   '24H_fluctate_rate': '13.10'},
#  'WAX': {'opening_price': '35',
#   'closing_price': '36',
#   'min_price': '34',
#   'max_price': '37.2',
#   'average_price': '35.2676',
#   'units_traded': '2481282.54340365',
#   'volume_1day': '2481282.54340365',
#   'volume_7day': '23282191.59414521',
#   'buy_price': '35.9',
#   'sell_price': '36.5',
#   '24H_fluctate': '1',
#   '24H_fluctate_rate': '2.85'},
#  'POWR': {'opening_price': '88.5',
#   'closing_price': '90.5',
#   'min_price': '84.4',
#   'max_price': '92.9',
#   'average_price': '88.9424',
#   'units_traded': '4505280.50441431',
#   'volume_1day': '4505280.50441431',
#   'volume_7day': '40538172.0353929',
#   'buy_price': '90.4',
#   'sell_price': '90.5',
#   '24H_fluctate': '2',
#   '24H_fluctate_rate': '2.25'},
#  'LRC': {'opening_price': '65.1',
#   'closing_price': '67.8',
#   'min_price': '61.6',
#   'max_price': '71.9',
#   'average_price': '65.2046',
#   'units_traded': '38463981.48706471',
#   'volume_1day': '38463981.48706471',
#   'volume_7day': '416893856.961858359145420525',
#   'buy_price': '67.5',
#   'sell_price': '67.8',
#   '24H_fluctate': '2.7',
#   '24H_fluctate_rate': '4.14'},
#  'GTO': {'opening_price': '27.6',
#   'closing_price': '27.8',
#   'min_price': '26.1',
#   'max_price': '29.9',
#   'average_price': '27.2069',
#   'units_traded': '3939052.52692439',
#   'volume_1day': '3939052.52692439',
#   'volume_7day': '56335751.49301947',
#   'buy_price': '27.5',
#   'sell_price': '27.8',
#   '24H_fluctate': '0.2',
#   '24H_fluctate_rate': '0.72'},
#  'STEEM': {'opening_price': '318',
#   'closing_price': '321',
#   'min_price': '311',
#   'max_price': '338',
#   'average_price': '323.0465',
#   'units_traded': '1230081.53504291',
#   'volume_1day': '1230081.53504291',
#   'volume_7day': '30477180.81519933',
#   'buy_price': '321',
#   'sell_price': '323',
#   '24H_fluctate': '3',
#   '24H_fluctate_rate': '0.94'},
#  'STRAT': {'opening_price': '913',
#   'closing_price': '949',
#   'min_price': '891',
#   'max_price': '981',
#   'average_price': '927.8204',
#   'units_traded': '153368.45591701',
#   'volume_1day': '153368.45591701',
#   'volume_7day': '1673304.10882782',
#   'buy_price': '938',
#   'sell_price': '949',
#   '24H_fluctate': '36',
#   '24H_fluctate_rate': '3.94'},
#  'ZRX': {'opening_price': '289',
#   'closing_price': '283',
#   'min_price': '276',
#   'max_price': '294',
#   'average_price': '282.6018',
#   'units_traded': '280709.36630129',
#   'volume_1day': '280709.36630129',
#   'volume_7day': '5669064.011365400856955878',
#   'buy_price': '282',
#   'sell_price': '284',
#   '24H_fluctate': '-6',
#   '24H_fluctate_rate': '-2.07'},
#  'REP': {'opening_price': '12790',
#   'closing_price': '13240',
#   'min_price': '12100',
#   'max_price': '13700',
#   'average_price': '12802.5106',
#   'units_traded': '230666.08951856',
#   'volume_1day': '230666.08951856',
#   'volume_7day': '1304774.55481132719480329',
#   'buy_price': '13240',
#   'sell_price': '13260',
#   '24H_fluctate': '450',
#   '24H_fluctate_rate': '3.51'},
#  'AE': {'opening_price': '403',
#   'closing_price': '404',
#   'min_price': '399',
#   'max_price': '417',
#   'average_price': '406.4615',
#   'units_traded': '601027.00931011',
#   'volume_1day': '601027.00931011',
#   'volume_7day': '5792395.12748261538776659',
#   'buy_price': '404',
#   'sell_price': '408',
#   '24H_fluctate': '1',
#   '24H_fluctate_rate': '0.24'},
#  'XEM': {'opening_price': '54.9',
#   'closing_price': '52',
#   'min_price': '50',
#   'max_price': '56.5',
#   'average_price': '53.1406',
#   'units_traded': '993818.38225281',
#   'volume_1day': '993818.38225281',
#   'volume_7day': '5676149.09301616',
#   'buy_price': '52',
#   'sell_price': '52.3',
#   '24H_fluctate': '-2.9',
#   '24H_fluctate_rate': '-5.28'},
#  'SNT': {'opening_price': '21.1',
#   'closing_price': '21.1',
#   'min_price': '20.2',
#   'max_price': '21.5',
#   'average_price': '20.8694',
#   'units_traded': '20718714.94928941',
#   'volume_1day': '20718714.94928941',
#   'volume_7day': '163724233.277067863454305041',
#   'buy_price': '21',
#   'sell_price': '21.1',
#   '24H_fluctate': '0',
#   '24H_fluctate_rate': '0.00'},
#  'ADA': {'opening_price': '43',
#   'closing_price': '41.9',
#   'min_price': '41.1',
#   'max_price': '43.6',
#   'average_price': '42.3559',
#   'units_traded': '9560449.37325356',
#   'volume_1day': '9560449.37325356',
#   'volume_7day': '51568115.2271158',
#   'buy_price': '41.7',
#   'sell_price': '41.8',
#   '24H_fluctate': '-1.1',
#   '24H_fluctate_rate': '-2.55'},
#  'PPT': {'opening_price': '1387',
#   'closing_price': '1313',
#   'min_price': '1308',
#   'max_price': '1417',
#   'average_price': '1349.7042',
#   'units_traded': '24287.96431115',
#   'volume_1day': '24287.96431115',
#   'volume_7day': '505136.12380547',
#   'buy_price': '1316',
#   'sell_price': '1391',
#   '24H_fluctate': '-74',
#   '24H_fluctate_rate': '-5.33'},
#  'CTXC': {'opening_price': '113',
#   'closing_price': '109',
#   'min_price': '105',
#   'max_price': '114',
#   'average_price': '109.5168',
#   'units_traded': '523525.83459439',
#   'volume_1day': '523525.83459439',
#   'volume_7day': '11537655.283517040273411807',
#   'buy_price': '109',
#   'sell_price': '110',
#   '24H_fluctate': '-4',
#   '24H_fluctate_rate': '-3.53'},
#  'CMT': {'opening_price': '26.4',
#   'closing_price': '25.7',
#   'min_price': '24.7',
#   'max_price': '26.7',
#   'average_price': '25.8781',
#   'units_traded': '6377212.8109724',
#   'volume_1day': '6377212.8109724',
#   'volume_7day': '46672882.425033466071624166',
#   'buy_price': '25.7',
#   'sell_price': '25.8',
#   '24H_fluctate': '-0.7',
#   '24H_fluctate_rate': '-2.65'},
#  'THETA': {'opening_price': '57.2',
#   'closing_price': '58.5',
#   'min_price': '54.4',
#   'max_price': '61.1',
#   'average_price': '57.1725',
#   'units_traded': '14540133.24333351',
#   'volume_1day': '14540133.24333351',
#   'volume_7day': '135937515.531906584001298508',
#   'buy_price': '58.2',
#   'sell_price': '58.6',
#   '24H_fluctate': '1.3',
#   '24H_fluctate_rate': '2.27'},
#  'WTC': {'opening_price': '1078',
#   'closing_price': '1100',
#   'min_price': '1060',
#   'max_price': '1148',
#   'average_price': '1093.5678',
#   'units_traded': '44768.28726633',
#   'volume_1day': '44768.28726633',
#   'volume_7day': '517480.752141901951337171',
#   'buy_price': '1100',
#   'sell_price': '1108',
#   '24H_fluctate': '22',
#   '24H_fluctate_rate': '2.04'},
#  'ITC': {'opening_price': '110',
#   'closing_price': '108',
#   'min_price': '108',
#   'max_price': '114',
#   'average_price': '110.2583',
#   'units_traded': '243338.30950909',
#   'volume_1day': '243338.30950909',
#   'volume_7day': '2866655.691509925359694232',
#   'buy_price': '108',
#   'sell_price': '110',
#   '24H_fluctate': '-2',
#   '24H_fluctate_rate': '-1.81'},
#  'TRUE': {'opening_price': '240',
#   'closing_price': '241',
#   'min_price': '235',
#   'max_price': '244',
#   'average_price': '239.3812',
#   'units_traded': '158291.21256667',
#   'volume_1day': '158291.21256667',
#   'volume_7day': '7059940.777850689086769364',
#   'buy_price': '241',
#   'sell_price': '242',
#   '24H_fluctate': '1',
#   '24H_fluctate_rate': '0.41'},
#  'ABT': {'opening_price': '72.6',
#   'closing_price': '70',
#   'min_price': '66',
#   'max_price': '76',
#   'average_price': '70.1884',
#   'units_traded': '354712.33366631',
#   'volume_1day': '354712.33366631',
#   'volume_7day': '5705720.455595016825588441',
#   'buy_price': '68.4',
#   'sell_price': '70',
#   '24H_fluctate': '-2.6',
#   '24H_fluctate_rate': '-3.58'},
#  'RNT': {'opening_price': '69.9',
#   'closing_price': '71.4',
#   'min_price': '68.7',
#   'max_price': '71.9',
#   'average_price': '70.3368',
#   'units_traded': '4062307.04342172',
#   'volume_1day': '4062307.04342172',
#   'volume_7day': '67002545.807917874702176911',
#   'buy_price': '71.4',
#   'sell_price': '71.9',
#   '24H_fluctate': '1.5',
#   '24H_fluctate_rate': '2.14'},
#  'PLY': {'opening_price': '30.6',
#   'closing_price': '28.6',
#   'min_price': '27.2',
#   'max_price': '30.6',
#   'average_price': '28.7358',
#   'units_traded': '5108448.29302712',
#   'volume_1day': '5108448.29302712',
#   'volume_7day': '33071197.359335043',
#   'buy_price': '28.6',
#   'sell_price': '28.8',
#   '24H_fluctate': '-2',
#   '24H_fluctate_rate': '-6.53'},
#  'WAVES': {'opening_price': '2800',
#   'closing_price': '3209',
#   'min_price': '2760',
#   'max_price': '3316',
#   'average_price': '3074.324',
#   'units_traded': '460601.89827017',
#   'volume_1day': '460601.89827017',
#   'volume_7day': '2994922.26000637',
#   'buy_price': '3176',
#   'sell_price': '3226',
#   '24H_fluctate': '409',
#   '24H_fluctate_rate': '14.60'},
#  'LINK': {'opening_price': '429',
#   'closing_price': '466',
#   'min_price': '393',
#   'max_price': '499',
#   'average_price': '447.0888',
#   'units_traded': '1863384.82195407',
#   'volume_1day': '1863384.82195407',
#   'volume_7day': '7542810.684926361433693523',
#   'buy_price': '461',
#   'sell_price': '467',
#   '24H_fluctate': '37',
#   '24H_fluctate_rate': '8.62'},
#  'ENJ': {'opening_price': '32.1',
#   'closing_price': '33.3',
#   'min_price': '31.4',
#   'max_price': '33.5',
#   'average_price': '32.5386',
#   'units_traded': '905374.5924',
#   'volume_1day': '905374.5924',
#   'volume_7day': '9975279.385484802878061005',
#   'buy_price': '31.8',
#   'sell_price': '33.3',
#   '24H_fluctate': '1.2',
#   '24H_fluctate_rate': '3.73'},
#  'PST': {'opening_price': '98.9',
#   'closing_price': '95.7',
#   'min_price': '93.6',
#   'max_price': '98.9',
#   'average_price': '96.9123',
#   'units_traded': '679223.6758',
#   'volume_1day': '679223.6758',
#   'volume_7day': '9747417.523360081746734577',
#   'buy_price': '95.6',
#   'sell_price': '95.7',
#   '24H_fluctate': '-3.2',
#   '24H_fluctate_rate': '-3.23'},
#  'SALT': {'opening_price': '243',
#   'closing_price': '232',
#   'min_price': '223',
#   'max_price': '251',
#   'average_price': '238.1282',
#   'units_traded': '820603.27036528',
#   'volume_1day': '820603.27036528',
#   'volume_7day': '4978334.60879428',
#   'buy_price': '232',
#   'sell_price': '233',
#   '24H_fluctate': '-11',
#   '24H_fluctate_rate': '-4.52'},
#  'RDN': {'opening_price': '232',
#   'closing_price': '227',
#   'min_price': '219',
#   'max_price': '242',
#   'average_price': '227.1795',
#   'units_traded': '565600.29624604',
#   'volume_1day': '565600.29624604',
#   'volume_7day': '8412803.777234199120712691',
#   'buy_price': '227',
#   'sell_price': '231',
#   '24H_fluctate': '-5',
#   '24H_fluctate_rate': '-2.15'},
#  'LOOM': {'opening_price': '44.6',
#   'closing_price': '43',
#   'min_price': '42.5',
#   'max_price': '46.4',
#   'average_price': '44.0751',
#   'units_traded': '1220809.45814518',
#   'volume_1day': '1220809.45814518',
#   'volume_7day': '5972380.461298338852353698',
#   'buy_price': '43',
#   'sell_price': '43.9',
#   '24H_fluctate': '-1.6',
#   '24H_fluctate_rate': '-3.58'},
#  'BHPC': {'opening_price': '756',
#   'closing_price': '756',
#   'min_price': '722',
#   'max_price': '771',
#   'average_price': '740.706',
#   'units_traded': '65585.07152767',
#   'volume_1day': '65585.07152767',
#   'volume_7day': '1690740.676525178709215767',
#   'buy_price': '755',
#   'sell_price': '756',
#   '24H_fluctate': '0',
#   '24H_fluctate_rate': '0.00'},
#  'PIVX': {'opening_price': '756',
#   'closing_price': '739',
#   'min_price': '708',
#   'max_price': '766',
#   'average_price': '742.0485',
#   'units_traded': '109275.55732937',
#   'volume_1day': '109275.55732937',
#   'volume_7day': '2923999.529097',
#   'buy_price': '737',
#   'sell_price': '748',
#   '24H_fluctate': '-17',
#   '24H_fluctate_rate': '-2.24'},
#  'INS': {'opening_price': '292',
#   'closing_price': '289',
#   'min_price': '273',
#   'max_price': '315',
#   'average_price': '288.2405',
#   'units_traded': '524597.44931971',
#   'volume_1day': '524597.44931971',
#   'volume_7day': '2894021.603014691',
#   'buy_price': '288',
#   'sell_price': '289',
#   '24H_fluctate': '-3',
#   '24H_fluctate_rate': '-1.02'},
#  'BCD': {'opening_price': '791',
#   'closing_price': '798',
#   'min_price': '768',
#   'max_price': '804',
#   'average_price': '787.7824',
#   'units_traded': '44053.32040635',
#   'volume_1day': '44053.32040635',
#   'volume_7day': '379255.58392483',
#   'buy_price': '778',
#   'sell_price': '799',
#   '24H_fluctate': '7',
#   '24H_fluctate_rate': '0.88'},
#  'BZNT': {'opening_price': '27.2',
#   'closing_price': '27.6',
#   'min_price': '26.6',
#   'max_price': '29.3',
#   'average_price': '27.5632',
#   'units_traded': '11515350.89133499',
#   'volume_1day': '11515350.89133499',
#   'volume_7day': '85021465.591501670871828034',
#   'buy_price': '27.3',
#   'sell_price': '27.5',
#   '24H_fluctate': '0.4',
#   '24H_fluctate_rate': '1.47'},
#  'XLM': {'opening_price': '99.2',
#   'closing_price': '93',
#   'min_price': '92.5',
#   'max_price': '101',
#   'average_price': '96.5276',
#   'units_traded': '16751507.68147604',
#   'volume_1day': '16751507.68147604',
#   'volume_7day': '80063368.88862906',
#   'buy_price': '92.9',
#   'sell_price': '93',
#   '24H_fluctate': '-6.2',
#   '24H_fluctate_rate': '-6.25'},
#  'OCN': {'opening_price': '2.63',
#   'closing_price': '2.58',
#   'min_price': '2.47',
#   'max_price': '2.68',
#   'average_price': '2.5831',
#   'units_traded': '23293450.26686245',
#   'volume_1day': '23293450.26686245',
#   'volume_7day': '208689104.466319115531188546',
#   'buy_price': '2.55',
#   'sell_price': '2.58',
#   '24H_fluctate': '-0.05',
#   '24H_fluctate_rate': '-1.90'},
#  'BSV': {'opening_price': '73900',
#   'closing_price': '70200',
#   'min_price': '68950',
#   'max_price': '74600',
#   'average_price': '71812.8274',
#   'units_traded': '19989.05490661',
#   'volume_1day': '19989.05490661',
#   'volume_7day': '76851.64316558',
#   'buy_price': '70200',
#   'sell_price': '70350',
#   '24H_fluctate': '-3700',
#   '24H_fluctate_rate': '-5.00'},
#  'TMTG': {'opening_price': '3.72',
#   'closing_price': '3.77',
#   'min_price': '3.66',
#   'max_price': '3.97',
#   'average_price': '3.7534',
#   'units_traded': '175642023.4720745',
#   'volume_1day': '175642023.4720745',
#   'volume_7day': '1820611163.595763313146719625',
#   'buy_price': '3.77',
#   'sell_price': '3.78',
#   '24H_fluctate': '0.05',
#   '24H_fluctate_rate': '1.34'},
#  'BAT': {'opening_price': '132',
#   'closing_price': '125',
#   'min_price': '121',
#   'max_price': '136',
#   'average_price': '127.1818',
#   'units_traded': '365011.61089412',
#   'volume_1day': '365011.61089412',
#   'volume_7day': '1862015.128165933404093117',
#   'buy_price': '123',
#   'sell_price': '133',
#   '24H_fluctate': '-7',
#   '24H_fluctate_rate': '-5.30'},
#  'WET': {'opening_price': '11.4',
#   'closing_price': '10.9',
#   'min_price': '10.7',
#   'max_price': '11.7',
#   'average_price': '11.253',
#   'units_traded': '34383047.15595679',
#   'volume_1day': '34383047.15595679',
#   'volume_7day': '133339260.041407795842369629',
#   'buy_price': '11',
#   'sell_price': '11.1',
#   '24H_fluctate': '-0.5',
#   '24H_fluctate_rate': '-4.38'},
#  'XVG': {'opening_price': '6.77',
#   'closing_price': '6.63',
#   'min_price': '6.45',
#   'max_price': '6.82',
#   'average_price': '6.656',
#   'units_traded': '12291608.92811147',
#   'volume_1day': '12291608.92811147',
#   'volume_7day': '129628515.03560361',
#   'buy_price': '6.63',
#   'sell_price': '6.65',
#   '24H_fluctate': '-0.14',
#   '24H_fluctate_rate': '-2.06'},
#  'IOST': {'opening_price': '6.46',
#   'closing_price': '6.15',
#   'min_price': '5.77',
#   'max_price': '6.47',
#   'average_price': '6.1414',
#   'units_traded': '27674764.78499825',
#   'volume_1day': '27674764.78499825',
#   'volume_7day': '142669128.777345919064806177',
#   'buy_price': '6.08',
#   'sell_price': '6.16',
#   '24H_fluctate': '-0.31',
#   '24H_fluctate_rate': '-4.79'},
#  'POLY': {'opening_price': '118',
#   'closing_price': '112',
#   'min_price': '110',
#   'max_price': '120',
#   'average_price': '114.2449',
#   'units_traded': '1354133.99279261',
#   'volume_1day': '1354133.99279261',
#   'volume_7day': '6215337.101428878752048366',
#   'buy_price': '111',
#   'sell_price': '112',
#   '24H_fluctate': '-6',
#   '24H_fluctate_rate': '-5.08'},
#  'HC': {'opening_price': '1069',
#   'closing_price': '1015',
#   'min_price': '990',
#   'max_price': '1070',
#   'average_price': '1024.5729',
#   'units_traded': '97146.99087553',
#   'volume_1day': '97146.99087553',
#   'volume_7day': '1060481.85830788',
#   'buy_price': '1014',
#   'sell_price': '1043',
#   '24H_fluctate': '-54',
#   '24H_fluctate_rate': '-5.05'},
#  'MEETONE': [],
#  'ADD': [],
#  'HORUS': [],
#  'CHL': [],
#  'EOSDAC': [],
#  'BLACK': [],
#  'ROM': {'opening_price': '0.09',
#   'closing_price': '0.09',
#   'min_price': '0.08',
#   'max_price': '0.09',
#   'average_price': '0.0868',
#   'units_traded': '1138446657.62715556',
#   'volume_1day': '1138446657.62715556',
#   'volume_7day': '12268310849.85968666653333332',
#   'buy_price': '0.08',
#   'sell_price': '0.09',
#   '24H_fluctate': '0',
#   '24H_fluctate_rate': '0.00'},
#  'AMO': {'opening_price': '0.68',
#   'closing_price': '0.66',
#   'min_price': '0.62',
#   'max_price': '0.7',
#   'average_price': '0.6594',
#   'units_traded': '247725901.4408343',
#   'volume_1day': '247725901.4408343',
#   'volume_7day': '3323001538.446889513637150208',
#   'buy_price': '0.66',
#   'sell_price': '0.67',
#   '24H_fluctate': '-0.02',
#   '24H_fluctate_rate': '-2.94'},
#  'ETZ': {'opening_price': '108',
#   'closing_price': '127',
#   'min_price': '108',
#   'max_price': '148',
#   'average_price': '132.0001',
#   'units_traded': '14759122.70952884',
#   'volume_1day': '14759122.70952884',
#   'volume_7day': '26250336.419095046853752182',
#   'buy_price': '127',
#   'sell_price': '129',
#   '24H_fluctate': '19',
#   '24H_fluctate_rate': '17.59'},
#  'ARN': {'opening_price': '286',
#   'closing_price': '286',
#   'min_price': '271',
#   'max_price': '308',
#   'average_price': '285.8044',
#   'units_traded': '354041.23347867',
#   'volume_1day': '354041.23347867',
#   'volume_7day': '1539543.17929098',
#   'buy_price': '275',
#   'sell_price': '284',
#   '24H_fluctate': '0',
#   '24H_fluctate_rate': '0.00'},
#  'APIS': {'opening_price': '1.98',
#   'closing_price': '2.07',
#   'min_price': '1.88',
#   'max_price': '2.34',
#   'average_price': '2.1094',
#   'units_traded': '862417751.0314877',
#   'volume_1day': '862417751.0314877',
#   'volume_7day': '29255658408.33404204471716559',
#   'buy_price': '2.06',
#   'sell_price': '2.07',
#   '24H_fluctate': '0.09',
#   '24H_fluctate_rate': '4.54'},
#  'MTL': {'opening_price': '256',
#   'closing_price': '254',
#   'min_price': '244',
#   'max_price': '270',
#   'average_price': '257.5226',
#   'units_traded': '329036.0237672',
#   'volume_1day': '329036.0237672',
#   'volume_7day': '5391955.04267233',
#   'buy_price': '254',
#   'sell_price': '269',
#   '24H_fluctate': '-2',
#   '24H_fluctate_rate': '-0.78'},
#  'date': '1548735371213'}
